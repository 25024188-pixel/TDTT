# %% [markdown]
# ### BAI 1

# %%
n = int(input())
print(n * 2)
# Out:
# 4

# %% [markdown]
# ### BAI 2

# %%
a = float(input())
b = float(input())
r = a / 2
s_hcn = a * b
s_tron = 3.14 * (r ** 2)
n = s_hcn - s_tron
print(f"{n:.2f}")
# Out:
# -89.04

# %% [markdown]
# ### BAI 3

# %%
n = input()
if n.isupper():
    print(n.lower())
else:
    print(n.upper())
# Out:
# N

# %% [markdown]
# ### BAI 4

# %%
n = input()
if n.isalpha():
    print(f"{n} la alphabet")
else:
    print(f"{n} khong phai la alphabet")
# Out:
# a la alphabet

# %% [markdown]
# ### BAI 5

# %%
n = input()
if n == 'A':
    print('z')
else:
    print(chr(ord(n.lower()) - 1))
# Out:
# z

# %% [markdown]
# ### BAI 6

# %%
a = float(input())
b = float(input())
c = float(input())

if a + b > c and a + c > b and b + c > a:
    p = (a + b + c) / 2
    n = (p * (p - a) * (p - b) * (p - c)) ** 0.5
else:
    n = "Khong phai 3 canh tam giac"
    print(n)
# Out:
# Khong phai 3 canh tam giac

# %% [markdown]
# ### BAI 7

# %%
n = input()
print(n[4], n[8])
# Out:
# f k

# %% [markdown]
# ### BAI 8

# %%
ten = input()
truoc = int(input())
nay = int(input())
so_dien = nay - truoc
tien = 0

if so_dien <= 50:
    tien = so_dien * 1984
elif so_dien <= 100:
    tien = 50 * 1984 + (so_dien - 50) * 2050
elif so_dien <= 200:
    tien = 50 * 1984 + 50 * 2050 + (so_dien - 100) * 2380
elif so_dien <= 300:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + (so_dien - 200) * 2998
elif so_dien <= 400:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (so_dien - 300) * 3350
else:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (so_dien - 400) * 3460

n = int(tien * 1.08)
print(ten)
print(n)
# Out:
# Du
# -289267
